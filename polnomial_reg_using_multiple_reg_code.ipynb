# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Input features
X = np.array([
    [1, 1],
    [2, 1],
    [3, 2],
    [4, 3],
    [5, 3]
])

# %%
# Target variable
y = np.array([20, 40, 50, 65, 80])

# %%
# Transform features to polynomial features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
# Train Polynomial Regression model
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Predictions
y_pred = model.predict(X_poly)

# %%
# Metrics
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Absolute Error: 1.2789769243681804e-14
# Mean Squared Error: 2.12045811323408e-28
# R2 Score: 1.0

# %%
# Plot actual vs predicted
plt.figure(figsize=(8,5))
plt.scatter(range(len(y)), y, color='black', label="Actual values")
plt.plot(range(len(y_pred)), y_pred, color='blue', marker='o', label="Predicted values")
plt.xlabel("Sample index")
plt.ylabel("Target Value")
plt.title("Polynomial Regression ")
plt.legend()
plt.show()
